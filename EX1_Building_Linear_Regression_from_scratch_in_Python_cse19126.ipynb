# %% [markdown]
# <a href="https://colab.research.google.com/github/darshan-jain/19CSE305-ML/blob/main/EX1_Building_Linear_Regression_from_scratch_in_Python_cse19126.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  19CSE305:Machine Learning
#
# ## Linear Regression:Gradient Descent

# %% [markdown]
# Linear Regression:
#
# **Y = wX + b**
#
# Y --> Dependent Variable
#
# X --> Independent Variable
#
# w --> weight
#
# b --> bias

# %% [markdown]
# **Gradient Descent:**
#
# Gradient Descent is an optimization algorithm used for minimizing the loss function in various machine learning algorithms. It is used for updating the parameters of the learning model.
#
# w  =  w - α*dw
#
# b  =  b - α*db

# %% [markdown]
# **Learning Rate:**
#
# Learning rate is a tuning parameter in an optimization algorithm that determines the step size at each iteration while moving toward a minimum of a loss function.

# %% [markdown]
# ![dw.png](data:image/png;base64,...)

# %% [markdown]
# ![db.png](data:image/png;base64,...)

# %%
# Making the imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# Preprocessing Input data
data = pd.read_csv('https://raw.githubusercontent.com/darshan-jain/19CSE305-ML/main/data1.csv')
X = data.iloc[:, 0] #get the independent variable
Y = data.iloc[:, 1] #get the dependent variable
plt.scatter(X, Y)  #plot the scatter plot
plt.show() # display the plot

# %%
# Building the model
m = 0
c = 0

L = 0.0001  # The learning Rate
epochs = 100000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print (m, c)
# Out:
# 1.380155614662503 5.175778331297034

# %% [markdown]
# **Linear Regression**

# %%
# Making predictions
Y_pred = m*X + c

plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red') # predicted
plt.show()

# %% [markdown]
# ## **Linear Regression using SKLEARN**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('https://raw.githubusercontent.com/darshan-jain/19CSE305-ML/main/data1.csv')
X = data.iloc[:, 0].values.reshape(-1, 1) # values converts it into a numpy array
Y = data.iloc[:, 1].values.reshape(-1, 1) # -1 means that calculate the dimension of rows, but have 1 column
LR = LinearRegression() #does all the calculations for linear reg 
LR.fit(X, Y) # fits the model with the values of X & Y. 
Y_pred =LR.predict(X)

# %% [markdown]
# In scikit-learn, an estimator for classification is a Python object that implements the methods fit(X, y) and predict(T).

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
print(LR.intercept_) # Yintercept
print(LR.coef_) #Slope
# Out:
# [9.90860619]
# [[1.28735737]]

# %% [markdown]
# # **Excercise 1**
# Download the dataset from the following link:
# https://drive.google.com/open?id=1oakZCv7g3mlmCSdv9J8kdSaqO5_6dIOw

# %%
# Displya first 5 records from the dataset

df = pd.read_csv('https://raw.githubusercontent.com/darshan-jain/19CSE305-ML/main/student_scores.csv')
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
#describe stats about the df
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
#Split the independent and dependent variables and plot the data
'''Write your code here

'''

X = df.iloc[:, 0].values.reshape(-1, 1) # values converts it into a numpy array
Y = df.iloc[:, 1].values.reshape(-1, 1) # -1 means that calculate the dimension of rows, but have 1 column

# %% [markdown]
# Explore  Scikit-Learn's built-in [train_test_split() ](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) method

# %%
#Split the data into train and test set :  80% of the data to training set and 20% data to test set
'''Write your code here
'''
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=None)

# %%
#Train an linear regression model and display the parameters (m,c)
'''Write your code here
'''
LR = LinearRegression() #does all the calculations for linear reg 
LR.fit(X, Y) # fits the model with the values of X & Y. 
Y_pred =LR.predict(X) 
m = LR.coef_
c = LR.intercept_
print(m,c)
# Out:
# [[9.77580339]] [2.48367341]

# %% [markdown]
# Explore sk learn predict method

# %%
#Make predictions for the test data
Y_pred =LR.predict(X)

# %%
#Display actual and predicted vlues
#print('Actual values: ', Y)
#print('Predicted Values:', Y_pred)

df = pd.DataFrame(data=Y, columns=['Actual Value'])
df['Predicted Value'] = Y_pred
df
# Out:
#     Actual Value  Predicted Value
# 0             21        26.923182
# 1             47        52.340271
# 2             27        33.766244
# 3             75        85.578002
# 4             30        36.698985
# 5             20        17.147378
# 6             88        92.421065
# 7             60        56.250592
# 8             81        83.622842
# 9             25        28.878343
# 10            85        77.757360
# 11            62        60.160913
# 12            41        46.474789
# 13            42        34.743825
# 14            17        13.237057
# 15            95        89.488324
# 16            30        26.923182
# 17            24        21.057700
# 18            67        62.116074
# 19            69        74.824618
# 20            30        28.878343
# 21            54        49.407530
# 22            35        39.631726
# 23            76        69.936717
# 24            86        78.734940
